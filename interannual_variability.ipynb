# %% [markdown]
# ## Wave varaince and ITCZ state interannual varaibility plotting
# Author: Fouzia Fahrin (ffahrin@iastate.edu)

# %%
import numpy as np 
import matplotlib.pyplot as plt
import xarray as xr
from netCDF4 import Dataset
import pandas as pd
import netCDF4
import datetime

from cartopy import config
import cartopy.crs as ccrs
import cartopy.feature as cfeature
from cartopy.util import add_cyclic_point

from mpl_toolkits.axes_grid1 import ImageGrid
# Out:
# ERROR 1: PROJ: proj_create_from_database: Open of /opt/miniconda3/envs/prod/share/proj failed

# %%
# open itcz state data
figfolder = './'

dri = '/home/ffahrin/test/IMERG/ITCZ_states/'
fn = 'IMERG_ITCZ_st_daily_EastPac_60prc.nc' #latest ITCZ state
data_itcz_st = xr.open_dataset(dri+fn)

# %%
time_all = data_itcz_st['time']

# %%
latitude=slice(-20., 20.)
longitude=slice(225,285)

# %%
# set up conditional statements 
cond_dITCZ = (data_itcz_st['itcz_state']==1)
cond_nITCZ = (data_itcz_st['itcz_state']==2)
cond_sITCZ = (data_itcz_st['itcz_state']==3)
cond_aITCZ = (data_itcz_st['itcz_state']==4)
cond_eITCZ = (data_itcz_st['itcz_state']==5)

# %%
time_2001 = data_itcz_st.sel(time=slice('2001-02-01T00:00:00.000000000','2001-04-30T00:00:00.000000000'))
time_dITCZ_2001 = len(time_2001['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2001 = len(time_2001['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2001 = len(time_2001['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2001 = len(time_2001['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2001 = len(time_2001['time'].where((cond_eITCZ), drop=True))

# %%
time_2002 = data_itcz_st.sel(time=slice('2002-02-01T00:00:00.000000000','2002-04-30T00:00:00.000000000'))
time_dITCZ_2002 = len(time_2002['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2002 = len(time_2002['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2002 = len(time_2002['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2002 = len(time_2002['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2002 = len(time_2002['time'].where((cond_eITCZ), drop=True))

# %%
time_2003 = data_itcz_st.sel(time=slice('2003-02-01T00:00:00.000000000','2003-04-30T00:00:00.000000000'))
time_dITCZ_2003 = len(time_2003['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2003 = len(time_2003['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2003 = len(time_2003['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2003 = len(time_2003['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2003 = len(time_2003['time'].where((cond_eITCZ), drop=True))

# %%
time_2004 = data_itcz_st.sel(time=slice('2004-02-01T00:00:00.000000000','2004-04-30T00:00:00.000000000'))
time_dITCZ_2004 = len(time_2004['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2004 = len(time_2004['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2004 = len(time_2004['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2004 = len(time_2004['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2004 = len(time_2004['time'].where((cond_eITCZ), drop=True))

# %%
time_2005 = data_itcz_st.sel(time=slice('2005-02-01T00:00:00.000000000','2005-04-30T00:00:00.000000000'))
time_dITCZ_2005 = len(time_2005['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2005 = len(time_2005['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2005 = len(time_2005['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2005 = len(time_2005['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2005 = len(time_2005['time'].where((cond_eITCZ), drop=True))

# %%
time_2006 = data_itcz_st.sel(time=slice('2006-02-01T00:00:00.000000000','2006-04-30T00:00:00.000000000'))
time_dITCZ_2006 = len(time_2006['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2006 = len(time_2006['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2006 = len(time_2006['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2006 = len(time_2006['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2006 = len(time_2006['time'].where((cond_eITCZ), drop=True))

# %%
time_2007 = data_itcz_st.sel(time=slice('2007-02-01T00:00:00.000000000','2007-04-30T00:00:00.000000000'))
time_dITCZ_2007 = len(time_2007['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2007 = len(time_2007['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2007 = len(time_2007['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2007 = len(time_2007['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2007 = len(time_2007['time'].where((cond_eITCZ), drop=True))

# %%
time_2008 = data_itcz_st.sel(time=slice('2008-02-01T00:00:00.000000000','2008-04-30T00:00:00.000000000'))
time_dITCZ_2008 = len(time_2008['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2008 = len(time_2008['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2008 = len(time_2008['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2008 = len(time_2008['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2008 = len(time_2008['time'].where((cond_eITCZ), drop=True))

# %%
time_2009 = data_itcz_st.sel(time=slice('2009-02-01T00:00:00.000000000','2009-04-30T00:00:00.000000000'))
time_dITCZ_2009 = len(time_2009['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2009 = len(time_2009['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2009 = len(time_2009['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2009 = len(time_2009['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2009 = len(time_2009['time'].where((cond_eITCZ), drop=True))

# %%
time_2010 = data_itcz_st.sel(time=slice('2010-02-01T00:00:00.000000000','2010-04-30T00:00:00.000000000'))
time_dITCZ_2010 = len(time_2010['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2010 = len(time_2010['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2010 = len(time_2010['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2010 = len(time_2010['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2010 = len(time_2010['time'].where((cond_eITCZ), drop=True))

# %%
time_2011 = data_itcz_st.sel(time=slice('2011-02-01T00:00:00.000000000','2011-04-30T00:00:00.000000000'))
time_dITCZ_2011 = len(time_2011['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2011 = len(time_2011['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2011 = len(time_2011['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2011 = len(time_2011['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2011 = len(time_2011['time'].where((cond_eITCZ), drop=True))

# %%
time_2012 = data_itcz_st.sel(time=slice('2012-02-01T00:00:00.000000000','2012-04-30T00:00:00.000000000'))
time_dITCZ_2012 = len(time_2012['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2012 = len(time_2012['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2012 = len(time_2012['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2012 = len(time_2012['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2012 = len(time_2012['time'].where((cond_eITCZ), drop=True))

# %%
time_2013 = data_itcz_st.sel(time=slice('2013-02-01T00:00:00.000000000','2013-04-30T00:00:00.000000000'))
time_dITCZ_2013 = len(time_2013['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2013 = len(time_2013['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2013 = len(time_2013['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2013 = len(time_2013['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2013 = len(time_2013['time'].where((cond_eITCZ), drop=True))

# %%
time_2014 = data_itcz_st.sel(time=slice('2014-02-01T00:00:00.000000000','2014-04-30T00:00:00.000000000'))
time_dITCZ_2014 = len(time_2014['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2014 = len(time_2014['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2014 = len(time_2014['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2014 = len(time_2014['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2014 = len(time_2014['time'].where((cond_eITCZ), drop=True))

# %%
time_2015 = data_itcz_st.sel(time=slice('2015-02-01T00:00:00.000000000','2015-04-30T00:00:00.000000000'))
time_dITCZ_2015 = len(time_2015['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2015 = len(time_2015['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2015 = len(time_2015['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2015 = len(time_2015['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2015 = len(time_2015['time'].where((cond_eITCZ), drop=True))

# %%
time_2016 = data_itcz_st.sel(time=slice('2016-02-01T00:00:00.000000000','2016-04-30T00:00:00.000000000'))
time_dITCZ_2016 = len(time_2016['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2016 = len(time_2016['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2016 = len(time_2016['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2016 = len(time_2016['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2016 = len(time_2016['time'].where((cond_eITCZ), drop=True))

# %%
time_2017 = data_itcz_st.sel(time=slice('2017-02-01T00:00:00.000000000','2017-04-30T00:00:00.000000000'))
time_dITCZ_2017 = len(time_2017['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2017 = len(time_2017['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2017 = len(time_2017['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2017 = len(time_2017['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2017 = len(time_2017['time'].where((cond_eITCZ), drop=True))

# %%
time_2018 = data_itcz_st.sel(time=slice('2018-02-01T00:00:00.000000000','2018-04-30T00:00:00.000000000'))
time_dITCZ_2018 = len(time_2018['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2018 = len(time_2018['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2018 = len(time_2018['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2018 = len(time_2018['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2018 = len(time_2018['time'].where((cond_eITCZ), drop=True))

# %%
time_2019 = data_itcz_st.sel(time=slice('2019-02-01T00:00:00.000000000','2019-04-30T00:00:00.000000000'))
time_dITCZ_2019 = len(time_2019['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2019 = len(time_2019['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2019 = len(time_2019['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2019 = len(time_2019['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2019 = len(time_2019['time'].where((cond_eITCZ), drop=True))

# %%
time_2020 = data_itcz_st.sel(time=slice('2020-02-01T00:00:00.000000000','2020-04-30T00:00:00.000000000'))
time_dITCZ_2020 = len(time_2020['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2020 = len(time_2020['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2020 = len(time_2020['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2020 = len(time_2020['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2020 = len(time_2020['time'].where((cond_eITCZ), drop=True))

# %%
time_2021 = data_itcz_st.sel(time=slice('2021-02-01T00:00:00.000000000','2021-04-30T00:00:00.000000000'))
time_dITCZ_2021 = len(time_2021['time'].where((cond_dITCZ), drop=True))
time_nITCZ_2021 = len(time_2021['time'].where((cond_nITCZ), drop=True))
time_sITCZ_2021 = len(time_2021['time'].where((cond_sITCZ), drop=True))
time_aITCZ_2021 = len(time_2021['time'].where((cond_aITCZ), drop=True))
time_eITCZ_2021 = len(time_2021['time'].where((cond_eITCZ), drop=True))

# %%
Double =   np.array([time_dITCZ_2001,time_dITCZ_2002,time_dITCZ_2003,time_dITCZ_2004,time_dITCZ_2005,time_dITCZ_2006,time_dITCZ_2007,time_dITCZ_2008,time_dITCZ_2009,time_dITCZ_2010,time_dITCZ_2011,time_dITCZ_2012,time_dITCZ_2013,time_dITCZ_2014,time_dITCZ_2015,time_dITCZ_2016,time_dITCZ_2017,time_dITCZ_2018,time_dITCZ_2019,time_dITCZ_2020,time_dITCZ_2021]) 
Northern = np.array([time_nITCZ_2001,time_nITCZ_2002,time_nITCZ_2003,time_nITCZ_2004,time_nITCZ_2005,time_nITCZ_2006,time_nITCZ_2007,time_nITCZ_2008,time_nITCZ_2009,time_nITCZ_2010,time_nITCZ_2011,time_nITCZ_2012,time_nITCZ_2013,time_nITCZ_2014,time_nITCZ_2015,time_nITCZ_2016,time_nITCZ_2017,time_nITCZ_2018,time_nITCZ_2019,time_nITCZ_2020,time_nITCZ_2021])
Southern = np.array([time_sITCZ_2001,time_sITCZ_2002,time_sITCZ_2003,time_sITCZ_2004,time_sITCZ_2005,time_sITCZ_2006,time_sITCZ_2007,time_sITCZ_2008,time_sITCZ_2009,time_sITCZ_2010,time_sITCZ_2011,time_sITCZ_2012,time_sITCZ_2013,time_sITCZ_2014,time_sITCZ_2015,time_sITCZ_2016,time_sITCZ_2017,time_sITCZ_2018,time_sITCZ_2019,time_sITCZ_2020,time_sITCZ_2021])
Equatorial = np.array([time_eITCZ_2001,time_eITCZ_2002,time_eITCZ_2003,time_eITCZ_2004,time_eITCZ_2005,time_eITCZ_2006,time_eITCZ_2007,time_eITCZ_2008,time_eITCZ_2009,time_eITCZ_2010,time_eITCZ_2011,time_eITCZ_2012,time_eITCZ_2013,time_eITCZ_2014,time_eITCZ_2015,time_eITCZ_2016,time_eITCZ_2017,time_eITCZ_2018,time_eITCZ_2019,time_eITCZ_2020,time_eITCZ_2021])
Absent = np.array([time_aITCZ_2001,time_aITCZ_2002,time_aITCZ_2003,time_aITCZ_2004,time_aITCZ_2005,time_aITCZ_2006,time_aITCZ_2007,time_aITCZ_2008,time_aITCZ_2009,time_aITCZ_2010,time_aITCZ_2011,time_aITCZ_2012,time_aITCZ_2013,time_aITCZ_2014,time_aITCZ_2015,time_aITCZ_2016,time_aITCZ_2017,time_aITCZ_2018,time_aITCZ_2019,time_aITCZ_2020,time_aITCZ_2021])

# %%
ls=30

# %%
data_prc = [list(Northern.flatten()),
list(Southern.flatten()),
list(Absent.flatten()),list(Double.flatten()), list(Equatorial.flatten())]

# %%
dri = '/lss/research/agon-lab/IMERG-daily/NASA_interpolated/equ_waves/'
fn = '1deg_IMERG_2000-2021_Kelvin.nc'
data_kvw = xr.open_dataset(dri+fn)

# %%
dri = '/lss/research/agon-lab/IMERG-daily/NASA_interpolated/equ_waves/'
fn = '1deg_IMERG_2000-2021_IG0.nc'
data_ig0 = xr.open_dataset(dri+fn)

# %%
dri = '/lss/research/agon-lab/IMERG-daily/NASA_interpolated/equ_waves/'
fn = '1deg_IMERG_2000-2021_TD-type.nc'
data_tdt = xr.open_dataset(dri+fn)

# %%
lats = 5
latn = 5
lonw = 250 #110W
lone = 250
lat_SHs=-5
lat_SHn=-5

# %%
var_kvw = data_kvw['precipitationCal'].sel(lat=slice(lats,latn),lon=slice(lonw,lone)).var(dim=('time'))
var_SH_kvw = data_kvw['precipitationCal'].sel(lat=slice(lat_SHs,lat_SHn),lon=slice(lonw,lone)).var(dim=('time'))

var_ig0 = data_ig0['precipitationCal'].sel(lat=slice(lats,latn),lon=slice(lonw,lone)).var(dim=('time'))
var_SH_ig0 = data_ig0['precipitationCal'].sel(lat=slice(lat_SHs,lat_SHn),lon=slice(lonw,lone)).var(dim=('time'))

var_tdt = data_tdt['precipitationCal'].sel(lat=slice(lats,latn),lon=slice(lonw,lone)).var(dim=('time'))
var_SH_tdt = data_tdt['precipitationCal'].sel(lat=slice(lat_SHs,lat_SHn),lon=slice(lonw,lone)).var(dim=('time'))

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_NH_kvw", "rb")
fma_prc_NH_kvw = np.load(file)
#print(fma_prc_NH_kvw)

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_SH_kvw", "rb")
fma_prc_SH_kvw = np.load(file)
#print(fma_prc_SH_kvw)

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_NH_ig0", "rb")
fma_prc_NH_ig0 = np.load(file)

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_SH_ig0", "rb")
fma_prc_SH_ig0 = np.load(file)

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_NH_tdt", "rb")
fma_prc_NH_tdt = np.load(file)

# %%
file = open("/home/ffahrin/test/IMERG/rolling_avg/fma_prc_SH_tdt", "rb")
fma_prc_SH_tdt = np.load(file)

# %%
number = ['(a)','(b)','(c)']
name = ['Kelvin','IG0','TD-type']

# %%
year = [2001, 2002, 2003, 2004,2005,2006,2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021]

# %%
fig = plt.figure(figsize=(30,30))# tight_layout='true')
fs=20
ls=20
wid=.15
npan=4
for j in range(0,npan,1):
    ax1 = fig.add_subplot(npan,1,j+1)
    plt.minorticks_on()
    ax1.tick_params(axis='x', labelsize=fs)
    ax1.tick_params(axis='y', labelsize=fs)
    if j == 3:
        color=["#FFFFFF","#DDAA33", "#BB5566","#004488", "#000000"]
        X=["2001","2002","2003","2004","2005","2006","2007","2008","2009","2010","2011","2012","2013","2014","2015","2016","2017","2018","2019","2020","2021"]
        X_axis = np.arange(len(X))
        plt0= plt.bar(X_axis, data_prc[0], color = color[0],label='Northern',width = wid,edgecolor= "k")
        plt1= plt.bar(X_axis+wid, data_prc[1], color = color[1], width = wid,edgecolor= "k",label='Southern')
        plt2= plt.bar(X_axis+(wid*2), data_prc[2], color = color[2], width = wid,edgecolor= "k",label='Absent')
        plt3= plt.bar(X_axis+(wid*3), data_prc[3], color = color[3], width = wid,edgecolor= "k",label='Double')
        plt4= plt.bar(X_axis+(wid*4), data_prc[4], color = color[4], width = wid,edgecolor= "k",label='Equatorial')
        plt.xticks((X_axis+(wid*2)), X)
        plt.tick_params(axis='both', which='major', length=10, width=1, direction='out', labelsize=ls)
        plt.xticks(rotation=0, fontsize=fs)
        plt.yticks(np.arange(0, 120, 20),rotation=0, fontsize=fs)
        plt.title("(d) ITCZ state distribution",fontsize=20, loc='left',fontweight="bold")
        plt.legend(loc="upper right", fontsize =fs,ncol=5)
        plt.ylabel("Number of Days",fontsize=fs,fontweight="bold",rotation=90,labelpad = .3)
        plt.xlabel("Year",fontsize=fs,fontweight="bold")
        plt.margins(x=0.02)
        #set(y, 'Units', 'Normalized', 'Position', [-0.1, 0.5, 0])
        #plt.set_ylabel('Y ',rotation=0)
        
    elif j == 0:
        plt.plot(year,fma_prc_NH_kvw,color='#BB5566',label="5$^{0}$N, 110$^{0}$W",linewidth=4)
        plt.plot(year,fma_prc_SH_kvw, color='#004488',label="5$^{0}$S, 110$^{0}$W",linewidth=4)
        plt.tick_params(axis='both', which='major', length=10, width=1, direction='out', labelsize=fs)
        plt.legend(loc="upper right")
        plt.axhline(var_SH_kvw, color='#004488', linewidth = 0.5,linestyle='--', zorder=2)
        plt.axhline(var_kvw, color='#BB5566', linewidth = 0.5,linestyle='--', zorder=2)

        plt.ylabel('Variance', fontsize=ls, fontweight="bold",labelpad = .5)
        #plt.xlabel('Year', fontsize=ls, fontweight="bold")
        plt.xticks(year,rotation=0, horizontalalignment="center", fontsize=ls)
        plt.yticks(np.arange(0, 120, 20),rotation=0, fontsize=ls)
        plt.minorticks_on()
        plt.margins(x=0.038)
        plt.legend(loc="upper right", fontsize =ls)
        plt.title(number[0]+' '+name[0], fontsize=fs, loc= 'left', fontweight="bold")
        
        
    elif j == 1:
        plt.plot(year,fma_prc_NH_ig0,color='#BB5566',label="5$^{0}$N, 110$^{0}$W",linewidth=4)
        plt.plot(year,fma_prc_SH_ig0, color='#004488',label="5$^{0}$S, 110$^{0}$W",linewidth=4)
        plt.tick_params(axis='both', which='major', length=10, width=1, direction='out', labelsize=fs)
        plt.legend(loc="upper right")
        plt.axhline(var_SH_ig0, color='#004488', linewidth = 0.5,linestyle='--', zorder=2)
        plt.axhline(var_ig0, color='#BB5566', linewidth = 0.5,linestyle='--', zorder=2)
        plt.ylabel('Variance', fontsize=ls, fontweight="bold",labelpad = 10)
        plt.xticks(year,rotation=0, horizontalalignment="center", fontsize=ls)
        plt.yticks(np.arange(0, 80, 10),rotation=0, fontsize=ls)
        plt.minorticks_on()
        plt.margins(x=0.04)
        plt.legend(loc="upper right", fontsize =ls)
        plt.title(number[1]+' '+name[1], fontsize=fs, loc= 'left', fontweight="bold")
        
        
    elif j == 2:
        plt.plot(year,fma_prc_NH_tdt,color='#BB5566',label="5$^{0}$N, 110$^{0}$W",linewidth=4)
        plt.plot(year,fma_prc_SH_tdt, color='#004488',label="5$^{0}$S, 110$^{0}$W",linewidth=4)
        plt.tick_params(axis='both', which='major', length=10, width=1, direction='out', labelsize=fs)
        plt.legend(loc="upper right")
        plt.axhline(var_SH_tdt, color='#004488', linewidth = 0.5,linestyle='--', zorder=2)
        plt.axhline(var_tdt, color='#BB5566', linewidth = 0.5,linestyle='--', zorder=2)
        plt.ylabel('Variance', fontsize=ls, fontweight="bold",labelpad = 10)
        #plt.xlabel('Year', fontsize=ls, fontweight="bold")
        plt.xticks(year,rotation=0, horizontalalignment="center", fontsize=ls)

        plt.yticks(np.arange(0, 60, 10),rotation=0, fontsize=ls)
        plt.title(number[2]+' '+name[2], fontsize=fs, loc= 'left',fontweight="bold")

        plt.minorticks_on()
        plt.margins(x=0.04)
        plt.legend(loc="upper right", fontsize =ls)
#plt.savefig(figfolder+'running_avg.pdf', bbox_inches="tight",transparent=False)#dpi=150)
